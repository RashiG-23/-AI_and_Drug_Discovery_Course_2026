# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "data"

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.9 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.2 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.3 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Step 1: Search for Traget Protein
#
# ## **Target Identification (KRAS)**
# Search ChEMBL for the KRAS target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("BRAF")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Mus musculus
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                            pref_name  score  \
# 0              Serine/threonine-protein kinase B-raf   19.0
# 1              Serine/threonine-protein kinase B-raf   17.0
# 2                                          BRAF/CRAF   17.0
# 3                              Protein cereblon/BRAF   16.0
# 4  B-raf/RAF proto-oncogene serine/threonine-prot...   15.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL2331061
# 1               False       CHEMBL5145
# 2               False    CHEMBL4106189
# 3               False    CHEMBL4523687
# 4               False    CHEMBL3883317
#
#                                    target_components  \
# 0  [{'accession': 'P28028', 'component_descriptio...
# 1  [{'accession': 'P15056', 'component_descriptio...
# 2  [{'accession': 'P04049', 'component_descriptio...
# 3  [{'accession': 'P15056', 'component_descriptio...
# 4  [{'accession': 'P04049', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN   10090
# 1               SINGLE PROTEIN    9606
# 2              PROTEIN COMPLEX    9606
# 3  PROTEIN-PROTEIN INTERACTION    9606
# 4               PROTEIN FAMILY    9606

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL5145'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **GTPase KRas(CHEMBL2189121)** with reported IC 50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1443255                  []
# 1        None             None      1666310                  []
# 2        None             None      1666311                  []
# 3        None             None      1666312                  []
# 4        None             None      1666313                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829087  Inhibition of Protein kinase Raf-B binding in ...
# 1    CHEMBL869911                    Inhibition bRaf kinase activity
# 2    CHEMBL869911                    Inhibition bRaf kinase activity
# 3    CHEMBL869911                    Inhibition bRaf kinase activity
# 4    CHEMBL869911                    Inhibition bRaf kinase activity
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                       target_pref_name target_tax_id  \
# 0    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 1    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 2    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 3    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 4    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
#
#   text_value  toid  type units    uo_units upper_value   value
# 0       None  None  IC50    uM  UO_0000065        None    16.0
# 1       None  None  IC50    nM  UO_0000065        None   900.0
# 2       None  None  IC50    nM  UO_0000065        None  1585.0
# 3       None  None  IC50    nM  UO_0000065        None   339.0
# 4       None  None  IC50    nM  UO_0000065        None    13.0
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in foler "data"**

# %%
! cp bioactivity_raw_data.csv "data"

# %%
! ls -l "data"
# Out:
# total 12404
# -rw-r--r-- 1 root root 12699254 Jan 27 09:29 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,1443255,[],CHEMBL829087,Inhibition of Protein kinase Raf-B binding in fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cccc(-c2n[nH]cc2-c2ccc3ncccc3n2)n1,,,CHEMBL1138735,J Med Chem,2004,,CHEMBL185238,GW786460X,CHEMBL185238,,0,http://www.openphacts.org/units/Nanomolar,372565,>,1,1,>,,IC50,nM,,16000.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,uM,UO_0000065,,16.0
# ,,1666310,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)(C)c1nc(-c2ccc(F)cc2)c(-c2ccncc2)[nH]1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '20.47', 'le': '0.38', 'lle': '1.47', 'sei': '14.54'}",CHEMBL371694,,CHEMBL371694,6.05,0,http://www.openphacts.org/units/Nanomolar,413171,=,1,1,=,,IC50,nM,,900.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,900.0
# ,,1666311,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,OCc1cccc(-c2[nH]c(-c3ccccc3)nc2-c2ccncc2)c1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '17.72', 'le': '0.32', 'lle': '1.50', 'sei': '9.39'}",CHEMBL200259,,CHEMBL200259,5.80,0,http://www.openphacts.org/units/Nanomolar,413191,=,1,1,=,,IC50,nM,,1585.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,1585.0
# ,,1666312,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,Oc1ccc(-c2[nH]c(-c3ccccc3)nc2-c2ccncc2)cc1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '20.65', 'le': '0.37', 'lle': '1.96', 'sei': '10.47'}",CHEMBL68215,,CHEMBL68215,6.47,0,http://www.openphacts.org/units/Nanomolar,413188,=,1,1,=,,IC50,nM,,339.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,339.0
# ,,1666313,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)(CNC(=O)Nc1ccc(Cl)cc1)c1nc(-c2ccc(Cl)c(O)c2)c(-c2ccncc2)[nH]1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '15.89', 'le': '0.32', 'lle': '1.64', 'sei': '7.66'}",CHEMBL200863,,CHEMBL200863,7.89,0,http://www.openphacts.org/units/Nanomolar,413181,=,1,1,=,,IC50,nM,,13.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,13.0
# ,,1666314,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)(CNS(C)(=O)=O)c1nc(-c2ccc(Cl)c(O)c2)c(-c2ccncc2)[nH]1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '18.66', 'le': '0.38', 'lle': '4.53', 'sei': '7.27'}",CHEMBL381447,,CHEMBL381447,7.85,0,http://www.openphacts.org/units/Nanomolar,413180,=,1,1,=,,IC50,nM,,14.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,14.0
# ,,1666315,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C)CCCNC(=O)c1nc(-c2ccc(Cl)c(O)c2)c(-c2ccncc2)[nH]1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '18.50', 'le': '0.36', 'lle': '4.22', 'sei': '7.86'}",CHEMBL426476,,CHEMBL426476,7.40,0,http://www.openphacts.org/units/Nanomolar,413179,=,1,1,=,,IC50,nM,,40.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,40.0
# ,,1666316,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)(CN)c1nc(-c2ccc(Cl)c(O)c2)c(-c2ccncc2)[nH]1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '23.98', 'le': '0.47', 'lle': '4.49', 'sei': '9.36'}",CHEMBL200889,,CHEMBL200889,8.22,0,http://www.openphacts.org/units/Nanomolar,413178,=,1,1,=,,IC50,nM,,6.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,6.0
# ,,1666317,[],CHEMBL869911,Inhibition bRaf kinase activity,B,,,BAO_0000190,BAO_0000357,single protein format,NCc1ccc(-c2nc(-c3ccc(Cl)c(O)c3)c(-c3ccncc3)[nH]2)cc1,,,CHEMBL1147772,Bioorg Med Chem Lett,2006,"{'bei': '21.49', 'le': '0.41', 'lle': '3.48', 'sei': '9.22'}",CHEMBL200320,,CHEMBL200320,8.10,0,http://www.openphacts.org/units/Nanomolar,413177,=,1,1,=,,IC50,nM,,8.0,CHEMBL5145,Homo sapiens,Serine/threonine-protein kinase B-raf,9606,,,IC50,nM,UO_0000065,,8.0

# %% [markdown]
# # **Step 3: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected KRAS target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1443255                  []
# 1        None             None      1666310                  []
# 2        None             None      1666311                  []
# 3        None             None      1666312                  []
# 4        None             None      1666313                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829087  Inhibition of Protein kinase Raf-B binding in ...
# 1    CHEMBL869911                    Inhibition bRaf kinase activity
# 2    CHEMBL869911                    Inhibition bRaf kinase activity
# 3    CHEMBL869911                    Inhibition bRaf kinase activity
# 4    CHEMBL869911                    Inhibition bRaf kinase activity
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                       target_pref_name target_tax_id  \
# 0    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 1    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 2    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 3    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
# 4    Homo sapiens  Serine/threonine-protein kinase B-raf          9606
#
#   text_value  toid  type units    uo_units upper_value   value
# 0       None  None  IC50    uM  UO_0000065        None    16.0
# 1       None  None  IC50    nM  UO_0000065        None   900.0
# 2       None  None  IC50    nM  UO_0000065        None  1585.0
# 3       None  None  IC50    nM  UO_0000065        None   339.0
# 4       None  None  IC50    nM  UO_0000065        None    13.0
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL185238              Cc1cccc(-c2n[nH]cc2-c2ccc3ncccc3n2)n1
# 1       CHEMBL371694        CC(C)(C)c1nc(-c2ccc(F)cc2)c(-c2ccncc2)[nH]1
# 2       CHEMBL200259        OCc1cccc(-c2[nH]c(-c3ccccc3)nc2-c2ccncc2)c1
# 3        CHEMBL68215         Oc1ccc(-c2[nH]c(-c3ccccc3)nc2-c2ccncc2)cc1
# 4       CHEMBL200863  CC(C)(CNC(=O)Nc1ccc(Cl)cc1)c1nc(-c2ccc(Cl)c(O)...
#
#   standard_value bioactivity_class
# 0        16000.0          inactive
# 1          900.0            active
# 2         1585.0      intermediate
# 3          339.0            active
# 4           13.0            active

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL185238              Cc1cccc(-c2n[nH]cc2-c2ccc3ncccc3n2)n1
# 1       CHEMBL371694        CC(C)(C)c1nc(-c2ccc(F)cc2)c(-c2ccncc2)[nH]1
# 2       CHEMBL200259        OCc1cccc(-c2[nH]c(-c3ccccc3)nc2-c2ccncc2)c1
# 3        CHEMBL68215         Oc1ccc(-c2[nH]c(-c3ccccc3)nc2-c2ccncc2)cc1
# 4       CHEMBL200863  CC(C)(CNC(=O)Nc1ccc(Cl)cc1)c1nc(-c2ccc(Cl)c(O)...
#
#   standard_value bioactivity_class
# 0        16000.0          inactive
# 1          900.0            active
# 2         1585.0      intermediate
# 3          339.0            active
# 4           13.0            active

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "data"
# !ls "data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
